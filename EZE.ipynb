# %% [markdown]
# # **Relatórios EZE - 19h**
# Formalização do código de leitura das tabelas dos relatórios EZE. O código foi desenvolvido no arquivo 'relatórios_EZE.ipynb'. Agora, vou fazer a leitura dos relatórios desde julho de 2023 e vou manter a leitura atualizada dos relatórios diários.

# %%
pip install ocr-nanonets-wrapper flatten_json json
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ocr-nanonets-wrapper in c:\users\mcavalari.vinci\appdata\roaming\python\python310\site-packages (1.1)
# Requirement already satisfied: flatten_json in c:\users\mcavalari.vinci\appdata\roaming\python\python310\site-packages (0.1.14)
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
from nanonets import NANONETSOCR
model = NANONETSOCR()
model.set_token('7514b653-993d-11ee-b34c-a61ebceb06aa')

# %%
import json
import pandas as pd

tables_json = model.convert_to_tables(input('Digite o caminho do arquivo PDF: '))
print(json.dumps(tables_json, indent=2))

arquivo_json = input('Digite o nome do arquivo JSON: ')

with open(arquivo_json, 'w', encoding='utf-8') as json_file:
    json.dump(tables_json, json_file, ensure_ascii=False, indent=2)

def json_to_excel(json_file_path, excel_file_path):
    with open(json_file_path, 'r') as file:
        data = json.load(file)

    table_data = {}
    page_offset = 0 # Armazena deslocamento das linhas baseado na página atual	

    for item in data:
        if 'prediction' in item:
            for prediction in item['prediction']:
                if 'cells' in prediction:
                    for cell in prediction['cells']:
                        row = cell['row'] + page_offset
                        col = cell['col']
                        text = cell.get('text', '')

                        if row not in table_data:
                            table_data[row] = {}
                        table_data[row][col] = text

                    page_offset += max([cell['row'] for cell in prediction['cells']]) 

    df = pd.DataFrame.from_dict(table_data, orient='index').sort_index(axis=0).sort_index(axis=1).fillna('')

    df.to_excel(excel_file_path, index=False)

json_file_path = arquivo_json
excel_file_path = input('Digite o caminho do arquivo Excel: ')

json_to_excel(json_file_path, excel_file_path)
# Out:
# [
#   {
#     "message": "Success",
#     "input": "Pre Trade Compliance Report Vinci_20240513070503.pdf",
#     "prediction": [
#       {
#         "id": "eba10430-a7ae-4ad5-bcdc-6e4539d1576d",
#         "label": "table",
#         "xmin": 2249,
#         "ymin": 153,
#         "xmax": 2907,
#         "ymax": 386,
#         "score": 1,
#         "ocr_text": "table",
#         "type": "table",
#         "cells": [
#           {
#             "id": "f61b47eb-7c95-4c91-8dc6-eda3dab19f4b",
#             "row": 1,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2249,
#             "ymin": 153,
#             "xmax": 2488,
#             "ymax": 211,
#             "score": 0.9082031,
#             "text": "Portfolio :",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "4b3393f4-9abd-4e11-9b54-cc33915e5f72",
#             "row": 1,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2488,
#             "ymin": 153,
#             "xmax": 2906,
#             "ymax": 211,
#             "score": 0.9453125,
#             "text": "<ALL>",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "da178049-3964-4fe3-8a88-577de08c4852",
#             "row": 2,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2249,
#             "ymin": 211,
#             "xmax": 2488,
#             "ymax": 271,
#             "score": 0.8857422,
#             "text": "Rule Name :",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "8b75fff6-a956-48ae-a6e9-80bb380656c5",
#             "row": 2,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2488,
#             "ymin": 211,
#             "xmax": 2906,
#             "ymax": 271,
#             "score": 0.921875,
#             "text": "<ALL>",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "0f45961a-a5be-4538-a9b4-da3e1bff5f54",
#             "row": 3,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2250,
#             "ymin": 271,
#             "xmax": 2489,
#             "ymax": 333,
#             "score": 0.8808594,
#             "text": "Start Date :",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "72cd4a9a-f935-49ce-a927-a358d213ff9e",
#             "row": 3,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2488,
#             "ymin": 270,
#             "xmax": 2906,
#             "ymax": 332,
#             "score": 0.9169922,
#             "text": "5/13/2024 12:00:00 AM",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "e5eab028-078e-41f3-8282-8f86b872dfbb",
#             "row": 4,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2250,
#             "ymin": 332,
#             "xmax": 2489,
#             "ymax": 386,
#             "score": 0.8979492,
#             "text": "End Date :",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "4d7db936-2035-4977-8ba4-3b4c9e6ad51b",
#             "row": 4,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2489,
#             "ymin": 332,
#             "xmax": 2907,
#             "ymax": 386,
#             "score": 0.9345703,
#             "text": "5/14/2024 12:00:00 AM",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           }
#         ],
#         "status": "correctly_predicted",
#         "page_no": 0,
#         "label_id": ""
#       },
#       {
#         "id": "a01cdbf1-2939-4f9b-8c26-5d72178eadc4",
#         "label": "table",
#         "xmin": 145,
#         "ymin": 597,
#         "xmax": 3149,
#         "ymax": 1572,
#         "score": 1,
#         "ocr_text": "table",
#         "type": "table",
#         "cells": [
#           {
#             "id": "799ad8bc-7290-43c3-95c0-19e90a0eda32",
#             "row": 1,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 145,
#             "ymin": 598,
#             "xmax": 312,
#             "ymax": 693,
#             "score": 0.82421875,
#             "text": "Run Time",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "e44a7f0a-b62f-4286-b9c9-a7ce0f3b4156",
#             "row": 1,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 312,
#             "ymin": 598,
#             "xmax": 897,
#             "ymax": 693,
#             "score": 0.82421875,
#             "text": "Rule Name",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "7db73a91-dd68-4aa8-af37-9613631116e9",
#             "row": 1,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 896,
#             "ymin": 598,
#             "xmax": 1515,
#             "ymax": 693,
#             "score": 0.9560547,
#             "text": "Compliance Message",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "392f1e90-2475-4f4f-9208-15d52489e116",
#             "row": 1,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1515,
#             "ymin": 598,
#             "xmax": 1813,
#             "ymax": 692,
#             "score": 0.8935547,
#             "text": "Related\nSymbol",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "9fe14873-f0c0-4c33-9997-bd8427e7c9b6",
#             "row": 1,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1813,
#             "ymin": 597,
#             "xmax": 1941,
#             "ymax": 692,
#             "score": 0.7001953,
#             "text": "Side",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "4a99cf3c-add8-4f2f-af6b-9d814b9616ba",
#             "row": 1,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1940,
#             "ymin": 597,
#             "xmax": 2171,
#             "ymax": 692,
#             "score": 0.90185547,
#             "text": "Error Level",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "f71771c7-1dfe-4759-aac2-0cbccf155787",
#             "row": 1,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2171,
#             "ymin": 597,
#             "xmax": 2645,
#             "ymax": 692,
#             "score": 0.9472656,
#             "text": "Override Message",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "34c02c52-9f5f-4702-91a8-756545228280",
#             "row": 1,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2645,
#             "ymin": 597,
#             "xmax": 2984,
#             "ymax": 692,
#             "score": 0.9086914,
#             "text": "Trade Went\nto Blotter",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "7037df4a-86ae-4253-94aa-8d5acc8031b0",
#             "row": 1,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2984,
#             "ymin": 597,
#             "xmax": 3147,
#             "ymax": 692,
#             "score": 0.82714844,
#             "text": "Trade ID",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "bdb157d8-9058-4c3a-aeec-a4766806afd0",
#             "row": 2,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 146,
#             "ymin": 693,
#             "xmax": 312,
#             "ymax": 754,
#             "score": 0.49804688,
#             "text": "Run Date",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "2ce4269c-5c66-423a-aaad-f038e5600659",
#             "row": 2,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 312,
#             "ymin": 693,
#             "xmax": 897,
#             "ymax": 754,
#             "score": 0.49804688,
#             "text": ": 05-13-2024",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "948b3d53-141a-40da-abff-03c4d0f97083",
#             "row": 2,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 897,
#             "ymin": 692,
#             "xmax": 1515,
#             "ymax": 754,
#             "score": 0.49804688,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "5f1c3a19-3d7f-4e92-b781-ccb09c49c6bf",
#             "row": 2,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1515,
#             "ymin": 692,
#             "xmax": 1813,
#             "ymax": 753,
#             "score": 0.49804688,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "bfb66161-0deb-49db-82ff-862f908e97e5",
#             "row": 2,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1813,
#             "ymin": 692,
#             "xmax": 1941,
#             "ymax": 753,
#             "score": 0.49804688,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "99cf87fb-5108-4c97-b1b4-ef06267d3113",
#             "row": 2,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1941,
#             "ymin": 692,
#             "xmax": 2171,
#             "ymax": 753,
#             "score": 0.49804688,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "939d63fd-70b1-4b8b-b927-edd138d61b9e",
#             "row": 2,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2171,
#             "ymin": 692,
#             "xmax": 2645,
#             "ymax": 753,
#             "score": 0.49804688,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "2685f9b7-eb79-4e96-8fd9-4e5c33d06b2f",
#             "row": 2,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2645,
#             "ymin": 692,
#             "xmax": 2984,
#             "ymax": 753,
#             "score": 0.49804688,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "435b1971-cbaf-4cb6-a0c8-db26cb9e8cc9",
#             "row": 2,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2984,
#             "ymin": 692,
#             "xmax": 3146,
#             "ymax": 752,
#             "score": 0.49804688,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "8d21d424-e419-4c54-8637-1b3b30b5abd0",
#             "row": 3,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 146,
#             "ymin": 754,
#             "xmax": 312,
#             "ymax": 814,
#             "score": 0.5830078,
#             "text": "Assignment:",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "fd1fa662-f35d-4564-93dd-72cf73e2379c",
#             "row": 3,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 312,
#             "ymin": 754,
#             "xmax": 897,
#             "ymax": 813,
#             "score": 0.5830078,
#             "text": "ATLAS",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "964d6ec3-034b-47a9-b120-d02b10e02dc2",
#             "row": 3,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 897,
#             "ymin": 753,
#             "xmax": 1515,
#             "ymax": 813,
#             "score": 0.5830078,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "bafcc61a-3a9e-4bd6-98ec-eae9e48d112c",
#             "row": 3,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1515,
#             "ymin": 753,
#             "xmax": 1813,
#             "ymax": 813,
#             "score": 0.5830078,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "bd080ea1-889a-45db-bd36-3d862897069d",
#             "row": 3,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1813,
#             "ymin": 753,
#             "xmax": 1941,
#             "ymax": 813,
#             "score": 0.5830078,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "1b848237-60b6-4674-b85e-00e3484360c4",
#             "row": 3,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1941,
#             "ymin": 753,
#             "xmax": 2171,
#             "ymax": 812,
#             "score": 0.5830078,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "7d1dc621-6532-4d1a-a030-b3411774d6e3",
#             "row": 3,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2171,
#             "ymin": 753,
#             "xmax": 2645,
#             "ymax": 812,
#             "score": 0.5830078,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "5b956a7f-8791-4a97-8353-641cc4d2a446",
#             "row": 3,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2645,
#             "ymin": 752,
#             "xmax": 2985,
#             "ymax": 812,
#             "score": 0.5830078,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "3acc684f-8eb8-48b1-9e62-b29a5faf75a3",
#             "row": 3,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2984,
#             "ymin": 752,
#             "xmax": 3147,
#             "ymax": 812,
#             "score": 0.5830078,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "77af8335-60ff-4c8b-8469-e6f9056eba31",
#             "row": 4,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 146,
#             "ymin": 813,
#             "xmax": 313,
#             "ymax": 908,
#             "score": 0.5126953,
#             "text": "16:35:49",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "20973ef9-cb51-4c44-89e0-108716ac3bcf",
#             "row": 4,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 312,
#             "ymin": 813,
#             "xmax": 897,
#             "ymax": 908,
#             "score": 0.8276367,
#             "text": "EQ 11 - Security Creation Check",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "5d2b9c0f-2be0-492b-87a8-32a23b3e90ea",
#             "row": 4,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 897,
#             "ymin": 813,
#             "xmax": 1516,
#             "ymax": 908,
#             "score": 0.92871094,
#             "text": "Security Type=\"EQ-BR\"",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "b81a370b-80b6-4446-8be6-9662bdc25e0f",
#             "row": 4,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1515,
#             "ymin": 813,
#             "xmax": 1813,
#             "ymax": 908,
#             "score": 0.8676758,
#             "text": "EQTL1 BZ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "d270f6ce-1e1f-4d81-84ea-78cbf341aec6",
#             "row": 4,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1813,
#             "ymin": 812,
#             "xmax": 1941,
#             "ymax": 907,
#             "score": 0.6801758,
#             "text": "BUY",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "996acaee-6162-4a5d-b60d-2ad321dc217e",
#             "row": 4,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1941,
#             "ymin": 812,
#             "xmax": 2172,
#             "ymax": 907,
#             "score": 0.87597656,
#             "text": "Restriction",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "ef8d6e90-4584-42af-85c9-f020c08fbe07",
#             "row": 4,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2171,
#             "ymin": 812,
#             "xmax": 2646,
#             "ymax": 907,
#             "score": 0.9199219,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "9a99ce08-a2b8-4bdf-97a9-d166bd35e8e4",
#             "row": 4,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2645,
#             "ymin": 812,
#             "xmax": 2985,
#             "ymax": 907,
#             "score": 0.8823242,
#             "text": "No",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "8447db23-8215-419f-9eb0-08e73f5439b3",
#             "row": 4,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2985,
#             "ymin": 812,
#             "xmax": 3147,
#             "ymax": 907,
#             "score": 0.80322266,
#             "text": "2024051\n300DJ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "21b851f8-ff9c-4ceb-9c14-e4cc460b4c73",
#             "row": 5,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 146,
#             "ymin": 908,
#             "xmax": 313,
#             "ymax": 1010,
#             "score": 0.51416016,
#             "text": "16:35:49",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "98ee9889-bd59-40da-a878-3b44874a95f2",
#             "row": 5,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 313,
#             "ymin": 908,
#             "xmax": 897,
#             "ymax": 1010,
#             "score": 0.8310547,
#             "text": "EQ 11 - Security Creation Check",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "055159d6-d2ae-4776-b05b-089d7ff6394b",
#             "row": 5,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 897,
#             "ymin": 908,
#             "xmax": 1516,
#             "ymax": 1009,
#             "score": 0.9316406,
#             "text": "Security Type=\"EQ-BR\"",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "6d68dc89-218e-483b-b5a0-2a72f0409882",
#             "row": 5,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1516,
#             "ymin": 907,
#             "xmax": 1814,
#             "ymax": 1009,
#             "score": 0.87109375,
#             "text": "EQTL1 BZ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "8bf1a4c5-bdf3-4c74-8869-459dcd938e37",
#             "row": 5,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1813,
#             "ymin": 907,
#             "xmax": 1942,
#             "ymax": 1009,
#             "score": 0.6826172,
#             "text": "BUY",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "9410a6de-5851-4abb-96b3-4c616bee6f2d",
#             "row": 5,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1941,
#             "ymin": 907,
#             "xmax": 2172,
#             "ymax": 1009,
#             "score": 0.87890625,
#             "text": "Restriction",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "0b478692-06a7-4e15-8392-110a378f9dab",
#             "row": 5,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2172,
#             "ymin": 907,
#             "xmax": 2646,
#             "ymax": 1009,
#             "score": 0.92333984,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "907b2bae-abd6-45ab-9358-a19b00cbbc04",
#             "row": 5,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2646,
#             "ymin": 907,
#             "xmax": 2985,
#             "ymax": 1008,
#             "score": 0.8857422,
#             "text": "No",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "b59bc400-23df-494b-b688-393e05064c24",
#             "row": 5,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2985,
#             "ymin": 907,
#             "xmax": 3148,
#             "ymax": 1008,
#             "score": 0.80615234,
#             "text": "2024051\n300DJ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "5d802722-3c28-4e3c-94dc-6c77d25fff73",
#             "row": 6,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 146,
#             "ymin": 1010,
#             "xmax": 313,
#             "ymax": 1105,
#             "score": 0.51171875,
#             "text": "16:35:51",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "2ed4635b-df77-4bc9-8a0c-acee36f72d82",
#             "row": 6,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 313,
#             "ymin": 1009,
#             "xmax": 898,
#             "ymax": 1105,
#             "score": 0.82666016,
#             "text": "EQ 11 - Security Creation Check",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "6166063f-68c3-4dfa-acab-04eae6ef1b30",
#             "row": 6,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 897,
#             "ymin": 1009,
#             "xmax": 1516,
#             "ymax": 1104,
#             "score": 0.9272461,
#             "text": "Security Type=\"EQ-BR\"",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "0b51b6ba-af47-47ed-9c56-92ec7e7ad472",
#             "row": 6,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1516,
#             "ymin": 1009,
#             "xmax": 1814,
#             "ymax": 1104,
#             "score": 0.8666992,
#             "text": "EQTL1 BZ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "f5fdab22-f9b5-4d48-9bb1-d3d2438295db",
#             "row": 6,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1814,
#             "ymin": 1009,
#             "xmax": 1942,
#             "ymax": 1104,
#             "score": 0.6791992,
#             "text": "BUY",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "90192621-08bd-4a1e-af22-75b9598fcf45",
#             "row": 6,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1942,
#             "ymin": 1009,
#             "xmax": 2172,
#             "ymax": 1104,
#             "score": 0.8745117,
#             "text": "Restriction",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "876c11f9-d280-4987-87d5-b6fcc0576bac",
#             "row": 6,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2172,
#             "ymin": 1008,
#             "xmax": 2646,
#             "ymax": 1104,
#             "score": 0.91845703,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "ac462737-0bb9-49c7-be5d-c7beb1453dbf",
#             "row": 6,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2646,
#             "ymin": 1008,
#             "xmax": 2986,
#             "ymax": 1103,
#             "score": 0.8808594,
#             "text": "No",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "89078e4e-8a5e-43b6-a564-efbe9844ca51",
#             "row": 6,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2985,
#             "ymin": 1008,
#             "xmax": 3148,
#             "ymax": 1103,
#             "score": 0.8017578,
#             "text": "2024051\n300DJ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "9fda0a60-d261-43a0-b527-f485428eaa29",
#             "row": 7,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 146,
#             "ymin": 1105,
#             "xmax": 313,
#             "ymax": 1204,
#             "score": 0.51708984,
#             "text": "16:35:51",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "95347081-28a0-4f0e-bb16-1a8353e1669d",
#             "row": 7,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 313,
#             "ymin": 1104,
#             "xmax": 898,
#             "ymax": 1204,
#             "score": 0.83496094,
#             "text": "EQ 11 - Security Creation Check",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "de3a53b4-ca76-45dc-bf50-d1bf1f4a4ee4",
#             "row": 7,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 898,
#             "ymin": 1104,
#             "xmax": 1516,
#             "ymax": 1204,
#             "score": 0.93652344,
#             "text": "Security Type=\"EQ-BR\"",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "e444cbc5-496e-4962-9090-9abd264143d2",
#             "row": 7,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1516,
#             "ymin": 1104,
#             "xmax": 1814,
#             "ymax": 1203,
#             "score": 0.8754883,
#             "text": "EQTL1 BZ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "c7275f91-2642-4b17-855e-a94136ef27b6",
#             "row": 7,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1814,
#             "ymin": 1104,
#             "xmax": 1942,
#             "ymax": 1203,
#             "score": 0.68603516,
#             "text": "BUY",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "adaa7aeb-f7d7-43bb-ac8b-f4046206d4c4",
#             "row": 7,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1942,
#             "ymin": 1104,
#             "xmax": 2172,
#             "ymax": 1203,
#             "score": 0.8833008,
#             "text": "Restriction",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "4c1065cf-3085-4d89-b4a4-d7bcb831761c",
#             "row": 7,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2172,
#             "ymin": 1103,
#             "xmax": 2646,
#             "ymax": 1203,
#             "score": 0.92822266,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "85bc234c-462f-42dd-99eb-143ebbbae7ac",
#             "row": 7,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2646,
#             "ymin": 1103,
#             "xmax": 2986,
#             "ymax": 1203,
#             "score": 0.8901367,
#             "text": "No",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "84ec9b7d-fe7c-42cd-8a67-c0ef8a0df53d",
#             "row": 7,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2986,
#             "ymin": 1103,
#             "xmax": 3148,
#             "ymax": 1202,
#             "score": 0.8100586,
#             "text": "2024051\n300DJ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "9a3e2394-3f3b-4505-a929-f773a3b1b7b0",
#             "row": 8,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 147,
#             "ymin": 1204,
#             "xmax": 314,
#             "ymax": 1300,
#             "score": 0.5073242,
#             "text": "16:36:23",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "541901e8-6829-4c86-9c90-16e95768ca2f",
#             "row": 8,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 313,
#             "ymin": 1204,
#             "xmax": 898,
#             "ymax": 1300,
#             "score": 0.81933594,
#             "text": "EQ 11 - Security Creation Check",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "ef931cd7-862c-44d5-9786-48a438542519",
#             "row": 8,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 898,
#             "ymin": 1203,
#             "xmax": 1517,
#             "ymax": 1300,
#             "score": 0.9189453,
#             "text": "Security Type=\"EQ-BR\"",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "a502cd7b-f906-4695-9418-dc937b646db2",
#             "row": 8,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1516,
#             "ymin": 1203,
#             "xmax": 1814,
#             "ymax": 1299,
#             "score": 0.8588867,
#             "text": "EQTL1 BZ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "c7b263b6-d511-4315-887a-2a0ea3f0607b",
#             "row": 8,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1814,
#             "ymin": 1203,
#             "xmax": 1942,
#             "ymax": 1299,
#             "score": 0.67333984,
#             "text": "BUY",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "decd23fc-1758-43b5-93bf-a7fa64159d78",
#             "row": 8,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1942,
#             "ymin": 1203,
#             "xmax": 2173,
#             "ymax": 1299,
#             "score": 0.8666992,
#             "text": "Restriction",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "036b428d-23d5-44ae-a6a1-632fbf510717",
#             "row": 8,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2172,
#             "ymin": 1203,
#             "xmax": 2647,
#             "ymax": 1299,
#             "score": 0.91064453,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "418cf5d3-a8b6-4707-849f-155789c11120",
#             "row": 8,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2646,
#             "ymin": 1202,
#             "xmax": 2986,
#             "ymax": 1299,
#             "score": 0.87353516,
#             "text": "No",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "816baf10-ca2d-44ba-b039-26873cd73638",
#             "row": 8,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2986,
#             "ymin": 1202,
#             "xmax": 3148,
#             "ymax": 1298,
#             "score": 0.7949219,
#             "text": "2024051\n300DJ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "9ef71a3d-7c2d-46ac-bd78-70af6620d98c",
#             "row": 9,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 147,
#             "ymin": 1300,
#             "xmax": 314,
#             "ymax": 1401,
#             "score": 0.5239258,
#             "text": "16:36:23",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "3fb85a70-520c-4c2c-81b9-68aa1f8c8d12",
#             "row": 9,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 314,
#             "ymin": 1300,
#             "xmax": 898,
#             "ymax": 1401,
#             "score": 0.8466797,
#             "text": "EQ 11 - Security Creation Check",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "acffb36c-b5be-4f98-8a96-f8527ddc7995",
#             "row": 9,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 898,
#             "ymin": 1299,
#             "xmax": 1517,
#             "ymax": 1400,
#             "score": 0.94921875,
#             "text": "Security Type=\"EQ-BR\"",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "2bb69917-ae72-4183-a78b-1c6e8992de7e",
#             "row": 9,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1517,
#             "ymin": 1299,
#             "xmax": 1815,
#             "ymax": 1400,
#             "score": 0.8876953,
#             "text": "EQTL1 BZ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "2ecdf468-ce7c-428b-9db5-db6a85b0867e",
#             "row": 9,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1814,
#             "ymin": 1299,
#             "xmax": 1943,
#             "ymax": 1399,
#             "score": 0.6953125,
#             "text": "BUY",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "0a8d2ba0-57b8-41b1-8034-223710e1ec5c",
#             "row": 9,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1942,
#             "ymin": 1299,
#             "xmax": 2173,
#             "ymax": 1399,
#             "score": 0.8955078,
#             "text": "Restriction",
# ...
#             "label": "",
#             "xmin": 2986,
#             "ymin": 1298,
#             "xmax": 3149,
#             "ymax": 1399,
#             "score": 0.82128906,
#             "text": "2024051\n300DJ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "6b21ac2d-5269-4c37-8ede-b4b7165875d7",
#             "row": 10,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 147,
#             "ymin": 1401,
#             "xmax": 314,
#             "ymax": 1458,
#             "score": 0.69433594,
#             "text": "Assignment:",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "2debdc44-b794-4b12-8eda-19be87cdf9e0",
#             "row": 10,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 314,
#             "ymin": 1400,
#             "xmax": 898,
#             "ymax": 1458,
#             "score": 0.69433594,
#             "text": "VINCI MOSAICO",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "aaa1a7e1-e3b2-4c14-8793-eb1d0c47ff38",
#             "row": 10,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 898,
#             "ymin": 1400,
#             "xmax": 1517,
#             "ymax": 1458,
#             "score": 0.69433594,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "1c93fb3b-54c5-4fb2-a752-cb87940de919",
#             "row": 10,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1517,
#             "ymin": 1399,
#             "xmax": 1815,
#             "ymax": 1457,
#             "score": 0.69433594,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "499e967b-f5bd-4d02-b2c6-25f976f6ef13",
#             "row": 10,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1815,
#             "ymin": 1399,
#             "xmax": 1943,
#             "ymax": 1457,
#             "score": 0.69433594,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "82335696-fd13-4c8c-ba60-b442d301f923",
#             "row": 10,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1943,
#             "ymin": 1399,
#             "xmax": 2173,
#             "ymax": 1457,
#             "score": 0.69433594,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "0aa7bf11-7349-433e-a1cb-d16d0d6b92b5",
#             "row": 10,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2173,
#             "ymin": 1399,
#             "xmax": 2647,
#             "ymax": 1457,
#             "score": 0.69433594,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "d496c2be-3574-410b-99ea-09c001d4a5fa",
#             "row": 10,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2647,
#             "ymin": 1399,
#             "xmax": 2987,
#             "ymax": 1456,
#             "score": 0.69433594,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "326f9f4d-13b9-4d3b-91b8-4242e4f4b1bf",
#             "row": 10,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2986,
#             "ymin": 1399,
#             "xmax": 3149,
#             "ymax": 1456,
#             "score": 0.69433594,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "b86144b5-4a73-4ae5-9ecf-6ffa78d410a0",
#             "row": 11,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 147,
#             "ymin": 1458,
#             "xmax": 314,
#             "ymax": 1520,
#             "score": 0.49804688,
#             "text": "16:08:22",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "ad29e2d4-8688-4f38-bb10-1fe23e3539cc",
#             "row": 11,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 314,
#             "ymin": 1458,
#             "xmax": 899,
#             "ymax": 1520,
#             "score": 0.8046875,
#             "text": "EQ 11 - Security Creation Check",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "39e7f970-52b4-4662-b4c3-eabd55f23819",
#             "row": 11,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 898,
#             "ymin": 1457,
#             "xmax": 1517,
#             "ymax": 1519,
#             "score": 0.90234375,
#             "text": "Security Type=\"EQ-BR\"",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "a0bb46d6-e3c5-47ec-9687-23adf3d9b972",
#             "row": 11,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1517,
#             "ymin": 1457,
#             "xmax": 1815,
#             "ymax": 1519,
#             "score": 0.8432617,
#             "text": "RENT9 BZ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "1ddc31ae-c7b9-45f4-b553-88778fb825e8",
#             "row": 11,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1815,
#             "ymin": 1457,
#             "xmax": 1943,
#             "ymax": 1519,
#             "score": 0.6611328,
#             "text": "SELL",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "fd49d263-f81f-4974-a8e1-a787913a3ae2",
#             "row": 11,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1943,
#             "ymin": 1457,
#             "xmax": 2173,
#             "ymax": 1519,
#             "score": 0.8510742,
#             "text": "Restriction",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "7365158d-7d7c-4c6c-b424-d3641eccef5b",
#             "row": 11,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2173,
#             "ymin": 1456,
#             "xmax": 2647,
#             "ymax": 1518,
#             "score": 0.89404297,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "44e62b6f-01a2-475b-9b26-101c23a43e22",
#             "row": 11,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2647,
#             "ymin": 1456,
#             "xmax": 2987,
#             "ymax": 1518,
#             "score": 0.8574219,
#             "text": "No",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "05a583d5-ab4b-403c-bcb5-7b4678160d94",
#             "row": 11,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2987,
#             "ymin": 1456,
#             "xmax": 3149,
#             "ymax": 1518,
#             "score": 0.7807617,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "f27ff2ac-c9b1-4d1f-b107-9315a6d36f97",
#             "row": 12,
#             "col": 1,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 147,
#             "ymin": 1520,
#             "xmax": 314,
#             "ymax": 1572,
#             "score": 0.50634766,
#             "text": "16:08:22",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "216cb6fb-227d-49da-9846-3827c0de177c",
#             "row": 12,
#             "col": 2,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 314,
#             "ymin": 1519,
#             "xmax": 899,
#             "ymax": 1572,
#             "score": 0.8178711,
#             "text": "EQ 11 - Security Creation Check",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "776bfd77-6cb6-4736-a85d-e086e86c3f78",
#             "row": 12,
#             "col": 3,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 899,
#             "ymin": 1519,
#             "xmax": 1517,
#             "ymax": 1571,
#             "score": 0.91748047,
#             "text": "Security Type=\"EQ-BR\"",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "99e68001-917b-4694-8619-dfa8ec177b0e",
#             "row": 12,
#             "col": 4,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1517,
#             "ymin": 1519,
#             "xmax": 1815,
#             "ymax": 1571,
#             "score": 0.85791016,
#             "text": "RENT9 BZ",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "3f1bf461-6aa9-4eeb-8c55-9416b3869ab0",
#             "row": 12,
#             "col": 5,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1815,
#             "ymin": 1519,
#             "xmax": 1943,
#             "ymax": 1571,
#             "score": 0.6723633,
#             "text": "SELL",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "317d56ab-b94e-4efb-baca-40d7c8c85257",
#             "row": 12,
#             "col": 6,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 1943,
#             "ymin": 1518,
#             "xmax": 2173,
#             "ymax": 1571,
#             "score": 0.86572266,
#             "text": "Restriction",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "afe6e91a-5262-4bd1-ac6d-b6f1cdaad314",
#             "row": 12,
#             "col": 7,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2173,
#             "ymin": 1518,
#             "xmax": 2647,
#             "ymax": 1571,
#             "score": 0.9091797,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "247546d1-196f-4d98-8d11-af8354e24e2c",
#             "row": 12,
#             "col": 8,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2647,
#             "ymin": 1518,
#             "xmax": 2987,
#             "ymax": 1570,
#             "score": 0.8720703,
#             "text": "No",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           },
#           {
#             "id": "1a448335-37fd-4249-ad8f-b036de6f52d6",
#             "row": 12,
#             "col": 9,
#             "row_span": 1,
#             "col_span": 1,
#             "label": "",
#             "xmin": 2987,
#             "ymin": 1518,
#             "xmax": 3149,
#             "ymax": 1570,
#             "score": 0.7939453,
#             "text": "",
#             "row_label": "",
#             "verification_status": "correctly_predicted",
#             "status": "",
#             "failed_validation": "",
#             "label_id": ""
#           }
#         ],
#         "status": "correctly_predicted",
#         "page_no": 0,
#         "label_id": ""
#       }
#     ],
#     "page": 0,
#     "request_file_id": "cdc4532a-d3bb-49bf-9625-d4e8f7b2f06c",
#     "filepath": "uploadedfiles/6aace346-9b80-4c02-8fd4-138c7575382c/PredictionImages/3439aa16-4164-459b-a885-580c3cdb8b27-1.jpeg",
#     "id": "fcdc0b9e-119c-11ef-87fd-0aeee5c40adb",
#     "rotation": 0,
#     "file_url": "uploadedfiles/6aace346-9b80-4c02-8fd4-138c7575382c/RawPredictions/cdc4532a-d3bb-49bf-9625-d4e8f7b2f06c.pdf",
#     "request_metadata": "",
#     "processing_type": "",
#     "size": {
#       "width": 3300,
#       "height": 2550
#     },
#     "raw_ocr_api_response": {
#       "results": null
#     }
#   }
# ]
